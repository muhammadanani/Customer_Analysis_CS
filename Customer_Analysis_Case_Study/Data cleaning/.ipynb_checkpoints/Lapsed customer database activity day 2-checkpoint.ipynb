# %% [markdown]
# ### Activity 1
#
# - Aggregate data into one Data Frame using Pandas.
# - Standardizing header names
# - Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints )
# - Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# - Removing duplicates
# - Replacing null values – Replace missing values with means of the column (for numerical columns)

# %%
import numpy as np
import pandas as pd

# %%
customer_df1 = pd.read_csv('data/file1.csv')
customer_df2 = pd.read_csv('data/file2.csv')
customer_df3= pd.read_csv('data/file3.csv')

# %%
##def make_heading_lowcase
def change_columns_header(df):
    df.columns = df.columns.str.lower()
    return df
change_columns_header(customer_df1)
change_columns_header(customer_df2)
change_columns_header(customer_df3)

def change_column_name(df, column_old_name, column_new_name):
    return df.rename(columns={column_old_name:column_new_name}, inplace= True)
def drop_columns(df, column_name):
    df.drop(columns=[column_name], inplace=True)
    return df
change_column_name(customer_df1, 'st', 'state')
change_column_name(customer_df2, 'st', 'state')

# %%
def rearrange_columns (df, list_of_new_column_names):
    ## list(df.columns)
    df = df[list_of_new_column_names]
    return df


new_column_names = list (customer_df1.columns)
new_column_names
customer_df2 = rearrange_columns (customer_df2, new_column_names)
customer_df3 = rearrange_columns (customer_df3, new_column_names)

# %%
customer_df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
customer_df2
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# 2                     112                    1/0/00   Personal Auto
# 3                     214                    1/1/00   Personal Auto
# 4                      94                    1/0/00  Corporate Auto
# ..                    ...                       ...             ...
# 991                    70                    1/0/00   Personal Auto
# 992                    68                    1/0/00  Corporate Auto
# 993                    70                    1/0/00  Corporate Auto
# 994                    96                    1/0/00   Personal Auto
# 995                   111                    1/0/00   Personal Auto
#
#      vehicle class  total claim amount
# 0    Four-Door Car          633.600000
# 1              SUV          547.200000
# 2     Two-Door Car          537.600000
# 3       Luxury Car         1027.200000
# 4     Two-Door Car          451.200000
# ..             ...                 ...
# 991  Four-Door Car          185.667213
# 992  Four-Door Car          140.747286
# 993   Two-Door Car          471.050488
# 994   Two-Door Car           28.460568
# 995            SUV          700.349052
#
# [996 rows x 11 columns]

# %%
customer_df = pd.concat([customer_df1, customer_df2, customer_df3], axis=0).reset_index(drop= True)

# %%
customer_df
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       number of open complaints     policy type  vehicle class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        total claim amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# 12070          379.200000
# 12071          790.784983
# 12072          691.200000
# 12073          369.600000
#
# [12074 rows x 11 columns]

# %% [markdown]
# Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints )
# Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns

# %%
customer_df['customer lifetime value'] = customer_df['customer lifetime value'].replace({'%':''}, regex= True)

# %%
customer_df['customer lifetime value'] = pd.to_numeric(customer_df['customer lifetime value'], errors='coerce')

# %%
customer_df['customer lifetime value'] = customer_df['customer lifetime value'].round(0)

# %%
replacement_dict = {
    "1/0/00": "0",
    "1/1/00": "1",
    "1/2/00": "2",
    "1/3/00": "3",
    "1/4/00": "4",
    "1/5/00": "5"
}
customer_df["number of open complaints"] = customer_df["number of open complaints"].replace(replacement_dict)

# %%
customer_df['number of open complaints'] = pd.to_numeric(customer_df['number of open complaints'], errors='coerce')

# %%
replacement_dict_state = {
    'WA': 'Washington',
    'AZ': 'Arizona',
    'Cali': 'California'
}
customer_df["state"] = customer_df["state"].replace(replacement_dict_state)

# %%
replacement_dict_gender = {
    'Femal': 'Female',
    'female': 'Female',
    'M': 'Male',
    'F': 'Female'
}
customer_df["gender"] = customer_df["gender"].replace(replacement_dict_gender)

# %%
customer_df = customer_df.drop_duplicates()

# %%
drop_columns(customer_df, 'customer')
# Out:
# /Users/muhammad/opt/anaconda3/envs/DA_Environment/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             state  gender             education  customer lifetime value  \
# 0      Washington     NaN                Master                      NaN
# 1         Arizona  Female              Bachelor                 697954.0
# 2          Nevada  Female              Bachelor                1288743.0
# 3      California    Male              Bachelor                 764586.0
# 4      Washington    Male  High School or Below                 536308.0
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor                  23406.0
# 12070  California  Female               College                   3097.0
# 12071  California    Male              Bachelor                   8164.0
# 12072  California    Male               College                   7524.0
# 12073  California    Male               College                   2612.0
#
#         income  monthly premium auto  number of open complaints  \
# 0          0.0                1000.0                        0.0
# 1          0.0                  94.0                        0.0
# 2      48767.0                 108.0                        0.0
# 3          0.0                 106.0                        0.0
# 4      36357.0                  68.0                        0.0
# ...        ...                   ...                        ...
# 12069  71941.0                  73.0                        0.0
# 12070  21604.0                  79.0                        0.0
# 12071      0.0                  85.0                        3.0
# 12072  21941.0                  96.0                        0.0
# 12073      0.0                  77.0                        0.0
#
#           policy type  vehicle class  total claim amount
# 0       Personal Auto  Four-Door Car            2.704934
# 1       Personal Auto  Four-Door Car         1131.464935
# 2       Personal Auto   Two-Door Car          566.472247
# 3      Corporate Auto            SUV          529.881344
# 4       Personal Auto  Four-Door Car           17.269323
# ...               ...            ...                 ...
# 12069   Personal Auto  Four-Door Car          198.234764
# 12070  Corporate Auto  Four-Door Car          379.200000
# 12071  Corporate Auto  Four-Door Car          790.784983
# 12072   Personal Auto  Four-Door Car          691.200000
# 12073  Corporate Auto   Two-Door Car          369.600000
#
# [9135 rows x 10 columns]

# %%
len(customer_df[customer_df['gender'].isna() == True])
# Out:
# 123

# %%
customer_df['gender'] = customer_df['gender'].fillna('Unknown')
# Out:
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/3205780690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['gender'] = customer_df['gender'].fillna('Unknown')

# %%
print(customer_df[customer_df['state'].isna() == True]) ## DELETE 1071
# Out:
#      state   gender education  customer lifetime value  income  \
# 1071   NaN  Unknown       NaN                      NaN     NaN
#
#       monthly premium auto  number of open complaints policy type  \
# 1071                   NaN                        NaN         NaN
#
#      vehicle class  total claim amount
# 1071           NaN                 NaN

# %%
print(customer_df[customer_df['number of open complaints'].isna() == True])
# Out:
#      state   gender education  customer lifetime value  income  \
# 1071   NaN  Unknown       NaN                      NaN     NaN
#
#       monthly premium auto  number of open complaints policy type  \
# 1071                   NaN                        NaN         NaN
#
#      vehicle class  total claim amount
# 1071           NaN                 NaN

# %%
customer_df.loc[1071, :]
# Out:
# state                            NaN
# gender                       Unknown
# education                        NaN
# customer lifetime value          NaN
# income                           NaN
# monthly premium auto             NaN
# number of open complaints        NaN
# policy type                      NaN
# vehicle class                    NaN
# total claim amount               NaN
# Name: 1071, dtype: object

# %%
## function to replace na in open complaints with 0 
customer_df['number of open complaints'] = customer_df['number of open complaints'].fillna(0)

## function that replaces 0 income with mean 
customer_df['income'] = customer_df['income'].replace(0, customer_df['income'].mean())
# Out:
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/2588910188.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['number of open complaints'] = customer_df['number of open complaints'].fillna(0)
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/2588910188.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['income'] = customer_df['income'].replace(0, customer_df['income'].mean())

# %%
def replace_null_mean (df_columns):
    df_columns = df_columns.fillna(df_columns.mean())
    return df_columns

# %%
replace_null_mean(customer_df['customer lifetime value'])

replace_null_mean(customer_df['monthly premium auto'])

replace_null_mean(customer_df['total claim amount'])
# Out:
# 0           2.704934
# 1        1131.464935
# 2         566.472247
# 3         529.881344
# 4          17.269323
#             ...
# 12069     198.234764
# 12070     379.200000
# 12071     790.784983
# 12072     691.200000
# 12073     369.600000
# Name: total claim amount, Length: 9135, dtype: float64

# %% [markdown]
# ## Activity 2

# %% [markdown]
# ### Activity 2
#
# - Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
# - Standardizing the data – Use string functions to standardize the text data (lower case)

# %%
customer_df["state"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan],
#       dtype=object)

# %%
replacement_dict_region = {
    'Washington': 'East',
    'Arizona': 'Central',
    'Nevada': 'Central',
    'California': 'West',
    'Oregon': 'North West'
}
customer_df['state'] = customer_df['state'].replace(replacement_dict_region)
# Out:
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/1826942966.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df['state'] = customer_df['state'].replace(replacement_dict_region)

# %%
customer_df
# Out:
#          state   gender             education  customer lifetime value  \
# 0         East  Unknown                Master                      NaN
# 1      Central   Female              Bachelor                 697954.0
# 2      Central   Female              Bachelor                1288743.0
# 3         West     Male              Bachelor                 764586.0
# 4         East     Male  High School or Below                 536308.0
# ...        ...      ...                   ...                      ...
# 12069     West     Male              Bachelor                  23406.0
# 12070     West   Female               College                   3097.0
# 12071     West     Male              Bachelor                   8164.0
# 12072     West     Male               College                   7524.0
# 12073     West     Male               College                   2612.0
#
#              income  monthly premium auto  number of open complaints  \
# 0      37824.847055                1000.0                        0.0
# 1      37824.847055                  94.0                        0.0
# 2      48767.000000                 108.0                        0.0
# 3      37824.847055                 106.0                        0.0
# 4      36357.000000                  68.0                        0.0
# ...             ...                   ...                        ...
# 12069  71941.000000                  73.0                        0.0
# 12070  21604.000000                  79.0                        0.0
# 12071  37824.847055                  85.0                        3.0
# 12072  21941.000000                  96.0                        0.0
# 12073  37824.847055                  77.0                        0.0
#
#           policy type  vehicle class  total claim amount
# 0       Personal Auto  Four-Door Car            2.704934
# 1       Personal Auto  Four-Door Car         1131.464935
# 2       Personal Auto   Two-Door Car          566.472247
# 3      Corporate Auto            SUV          529.881344
# 4       Personal Auto  Four-Door Car           17.269323
# ...               ...            ...                 ...
# 12069   Personal Auto  Four-Door Car          198.234764
# 12070  Corporate Auto  Four-Door Car          379.200000
# 12071  Corporate Auto  Four-Door Car          790.784983
# 12072   Personal Auto  Four-Door Car          691.200000
# 12073  Corporate Auto   Two-Door Car          369.600000
#
# [9135 rows x 10 columns]

# %%
def change_all_lower (df_column):
        df_column = df_column.str.lower()
        return df_column

# %%
(customer_df["state"]) = change_all_lower(customer_df['state'])
(customer_df["education"]) = change_all_lower(customer_df["education"])
(customer_df["gender"]) = change_all_lower(customer_df["gender"])
(customer_df["policy type"]) = change_all_lower(customer_df["policy type"])
(customer_df["vehicle class"]) = change_all_lower(customer_df["vehicle class"])
# Out:
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/106176228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (customer_df["state"]) = change_all_lower(customer_df['state'])
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/106176228.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (customer_df["education"]) = change_all_lower(customer_df["education"])
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/106176228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (customer_df["gender"]) = change_all_lower(customer_df["gender"])
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/106176228.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (customer_df["policy type"]) = change_all_lower(customer_df["policy type"])
# /var/folders/g0/t2l0bdnj06l1ns109451lxvw0000gp/T/ipykernel_61283/106176228.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   (customer_df["vehicle class"]) = change_all_lower(customer_df["vehicle class"])

# %%
customer_df
# Out:
#          state   gender             education  customer lifetime value  \
# 0         east  unknown                master                      NaN
# 1      central   female              bachelor                 697954.0
# 2      central   female              bachelor                1288743.0
# 3         west     male              bachelor                 764586.0
# 4         east     male  high school or below                 536308.0
# ...        ...      ...                   ...                      ...
# 12069     west     male              bachelor                  23406.0
# 12070     west   female               college                   3097.0
# 12071     west     male              bachelor                   8164.0
# 12072     west     male               college                   7524.0
# 12073     west     male               college                   2612.0
#
#              income  monthly premium auto  number of open complaints  \
# 0      37824.847055                1000.0                        0.0
# 1      37824.847055                  94.0                        0.0
# 2      48767.000000                 108.0                        0.0
# 3      37824.847055                 106.0                        0.0
# 4      36357.000000                  68.0                        0.0
# ...             ...                   ...                        ...
# 12069  71941.000000                  73.0                        0.0
# 12070  21604.000000                  79.0                        0.0
# 12071  37824.847055                  85.0                        3.0
# 12072  21941.000000                  96.0                        0.0
# 12073  37824.847055                  77.0                        0.0
#
#           policy type  vehicle class  total claim amount
# 0       personal auto  four-door car            2.704934
# 1       personal auto  four-door car         1131.464935
# 2       personal auto   two-door car          566.472247
# 3      corporate auto            suv          529.881344
# 4       personal auto  four-door car           17.269323
# ...               ...            ...                 ...
# 12069   personal auto  four-door car          198.234764
# 12070  corporate auto  four-door car          379.200000
# 12071  corporate auto  four-door car          790.784983
# 12072   personal auto  four-door car          691.200000
# 12073  corporate auto   two-door car          369.600000
#
# [9135 rows x 10 columns]

# %% [markdown]
# ### Activity 4
#
# - Get the numeric data into dataframe called `numerical` and categorical columns in a dataframe called `categoricals`.
# (You can use np.number and np.object to select the numerical data types and categorical data types respectively)
# - Now we will try to check the normality of the numerical variables visually
#   - Use seaborn library to construct distribution plots for the numerical variables
#   - Use Matplotlib to construct histograms
#   - Do the distributions for different numerical variables look like a normal distribution
# - For the numerical variables, check the multicollinearity between the features. Please note that we will use the column `total_claim_amount` later as the target variable.
# - Drop one of the two features that show a high correlation between them (greater than 0.9). If there is no pair of features that have a high correlation, then do not drop any features.
