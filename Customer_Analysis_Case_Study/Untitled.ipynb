# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# For this lab, we will be using the same dataset for the customer analysis case study we used in the previous labs. We recommend using the same notebook since you will be reusing the same variables you previous created and used in labs.
#
# Instructions
# Define a function that takes a list of models and train (and tests) them so we can try a lot of them without repeating code.
# Use the function to check LinearRegressor,Lasso,Ridge and KNeighborsRegressor.
# Use feature selection techniques to select subset of features to train the model with(if necessary).
# Check and discuss the results.

# %%
customer_df = pd.read_csv('Data_Marketing_Customer_Analysis_Round2.csv')
customer_df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
custumer_df_numeric = customer_df._get_numeric_data()
custumer_df_numeric = custumer_df_numeric.dropna()
X = custumer_df_numeric
# Out:
#        Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 5               5              4745.181764   50549                    61
# ...           ...                      ...     ...                   ...
# 10904       10904             19228.463620       0                   187
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# ...

# %%
X = custumer_df_numeric
y = np.log(X['Total Claim Amount'])

# %%
## define a function that trains and tests
rs = 123
def xy_transform_split(df, target_column, test_size=0.2):
    
    X = df
    y = np.log(df['target_column'])
    
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size, random_state=42)

    X_train = pd.df(X_train, columns=X.columns)
    X_test  = pd.df(X_test, columns=X.columns)
    
    X_train = X_train.select_dtypes(include=np.number)
    X_test  = X_test.select_dtypes(include=np.number)
    
    
    
    return
